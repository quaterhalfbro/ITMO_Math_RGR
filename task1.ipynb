# %%
from source import *
import numpy as np

# %% [markdown]
# # Task 1
#
# $f(x) = e^x$
#
# $[a, b] = [-2, 2]$
#
# **Интегральная сумма**
#
# 1. Составьте и изобразите интегральную сумму функции на заданном отрезке в виде ступенчатой фигуры:
#     * Изобразите график функции.
#     * Изобразите криволинейную трапецию, ограниченную графиком функции, вертикальными прямыми, проходящими через концы отрезка, и осью Ox.
#     * Разбейте отрезок на n элементарных отрезков, точками отметьте их концы на рисунке.
#     * Выберите по одной точке внутри каждого элементарного отрезка, отметьте их на рисунке.
#     * Вычислите значения функции в выбранных точках, отметьте их на рисунке.
#     * Изобразите ступенчатую фигуру на основе выбранного разбиения и точек внутри элементарных отрезков.

# %%
a, b = -2, 2
x = np.linspace(a - 1, b + 1, 10000)
y = np.exp(x)

simple_plot(x, y)

# %%
plot_with_trapecy(x, y, a, b)

# %%
plot_with_extra_points(x, y, a, b, 6, "center")

# %%
plot_with_steps_figure(x, y, a, b, 6, "center")

# %% [markdown]
# 2. Исследуйте ступенчатую фигуру. Для этого выберите количество ступеней  (от 3 до 5) и посмотрите, как изменяется фигура при смещении точек внутри элементарных отрезков (рассмотрите три положения точек: крайнее левое, крайнее правое и промежуточное на выбор). Затем выберите другое количество ступеней  (от 6 до 10), а затем (от 11 и больше) и повторите процедуру.

# %%
plot_with_steps_figure(x, y, a, b, 40, "center")

# %% [markdown]
# 3. Сделайте заключение.
#
# При количестве отрезков на которые мы разбиваем Ox, сумма площадей прямоугольников стремится к площади фигуры.

# %% [markdown]
# **Последовательность интегральных сумм**

# %% [markdown]
# 1. Постройте интегральную сумму функции на заданном отрезке.
# 2. Исследуйте её значение с ростом n при различных положениях точек внутри элементарных отрезков (рассмотрите три положения: крайнее левое, крайнее правое и промежуточное на выбор).

# %%
squares_plot(a, b)

# %% [markdown]
# Независимо от выбора точки, в которой мы берём значение функции на отрезке, сумма их площадей стримится к одной величине.

# %% [markdown]
# 3. Вычислите интеграл от данной функции по отрезку аналитически и сравните значения интегральных сумм с его величиной.

# %% [markdown]
# $\int^2_{-2}{e^x}{\rm d}x = e^2 - e^{-2}$

# %%
analytic_value = np.exp(2) - np.exp(-2)
program_value = get_square(a, b, 10000, "center")

(analytic_value - program_value)**2
# Out:
# 9.353887005610423e-15

# %% [markdown]
# 4. Сделайте заключение

# %% [markdown]
# * При количестве отрезков стремящемся к бесконечности, площадь ступенчатой фигуры стремится к площади под графиком.
# * Это происходит в независимости от выбора точки на отрезке.
